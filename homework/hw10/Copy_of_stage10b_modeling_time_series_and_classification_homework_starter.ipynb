# %% [markdown]
# <a href="https://colab.research.google.com/github/Leo-xxx12/bootcamp_Leo_Xu/blob/main/Copy_of_stage10b_modeling_time_series_and_classification_homework_starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework Starter — Stage 10b: Time Series & Classification
# Fill in the TODOs. Use your own dataset or adapt the synthetic generator below.

# %%
# Imports
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_absolute_error, mean_squared_error, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split, TimeSeriesSplit
np.random.seed(7); sns.set(); plt.rcParams['figure.figsize']=(9,4)

# %% [markdown]
# ## Option A: Use Your Own Data (Recommended)
# Load your data here (ensure a DateTime index for time series).

# %%
# TODO: load your data
# df = pd.read_csv('path/to.csv', parse_dates=['Date'], index_col='Date')

# %% [markdown]
# ## Option B: Synthetic Generator (Use if you don't have data ready)

# %%
# Synthetic series with regimes & jumps
n=500
dates=pd.bdate_range('2021-01-01', periods=n)
mu = np.where(np.arange(n)<n//2, 0.0003, -0.0001)
sigma = np.where(np.arange(n)<n//2, 0.01, 0.015)
eps = np.random.normal(mu, sigma)
jumps = np.zeros(n); jump_days = np.random.choice(np.arange(20,n-20), size=5, replace=False)
jumps[jump_days] = np.random.normal(0,0.05,size=len(jump_days))
rets = eps + jumps
price = 100*np.exp(np.cumsum(rets))
df = pd.DataFrame({'price':price}, index=dates)
df['ret'] = df['price'].pct_change().fillna(0.0)
df['log_ret'] = np.log1p(df['ret'])
df.head()
# Out:
#                  price       ret   log_ret
# 2021-01-01  101.735412  0.000000  0.000000
# 2021-01-04  101.292875 -0.004350 -0.004359
# 2021-01-05  101.356527  0.000628  0.000628
# 2021-01-06  101.800950  0.004385  0.004375
# 2021-01-07  101.031283 -0.007561 -0.007589

# %% [markdown]
# ## Feature Engineering

# %%
# TODO: create at least two features
df['lag_1'] = df['ret'].shift(1)
df['roll_mean_5'] = df['ret'].rolling(5).mean().shift(1)
# Add your own:
# df['roll_vol_20'] = df['ret'].rolling(20).std().shift(1)
# Rolling volatility over 20 days (risk measure)
df['roll_vol_20'] = df['ret'].rolling(20).std().shift(1)

# Momentum: difference between short- and long-term moving averages
df['mom_5_20'] = df['ret'].rolling(5).mean().shift(1) - df['ret'].rolling(20).mean().shift(1)

# Rolling skewness (captures asymmetry in return distribution)
df['roll_skew_20'] = df['ret'].rolling(20).skew().shift(1)

df['y_next_ret'] = df['ret'].shift(-1)
df['y_up'] = (df['y_next_ret']>0).astype(int)
df_feat = df.dropna().copy()
df_feat.head()
# Out:
#                  price       ret   log_ret     lag_1  roll_mean_5  y_next_ret  \
# 2021-01-29  100.198878  0.016949  0.016807 -0.014854    -0.003707    0.001845
# 2021-02-01  100.383751  0.001845  0.001843  0.016949     0.002509   -0.003565
# 2021-02-02  100.025880 -0.003565 -0.003571  0.001845     0.001706    0.020804
# 2021-02-03  102.106835  0.020804  0.020591 -0.003565     0.000685   -0.000154
# 2021-02-04  102.091126 -0.000154 -0.000154  0.020804     0.004236   -0.014106
#
#             y_up  roll_vol_20  mom_5_20  roll_skew_20
# 2021-01-29     1     0.007370 -0.002133     -0.730887
# 2021-02-01     0     0.008455  0.003236     -0.204772
# 2021-02-02     1     0.008429  0.002123     -0.322945
# 2021-02-03     0     0.008453  0.001311     -0.240552
# 2021-02-04     0     0.009675  0.004041      0.183465

# %% [markdown]
# ## Split

# %%
# Time-aware split
cut=int(len(df_feat)*0.8)
train, test = df_feat.iloc[:cut], df_feat.iloc[cut:]
features=['lag_1','roll_mean_5']  # extend as you add features
X_tr, X_te = train[features], test[features]
y_tr_reg, y_te_reg = train['y_next_ret'], test['y_next_ret']
y_tr_clf, y_te_clf = train['y_up'], test['y_up']

# %% [markdown]
# ## Pipeline + Model (Choose one track below)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

# Track 1: Forecasting returns
reg = Pipeline([
    ('scaler', StandardScaler()),
    ('linreg', LinearRegression())
])

reg.fit(X_tr, y_tr_reg)
pred = reg.predict(X_te)

# RMSE calculation
rmse = np.sqrt(mean_squared_error(y_te_reg, pred))
print('RMSE:', rmse)
# Out:
# RMSE: 0.014484996137727905

# %%
# Track 2: Classification (up/down)
clf = Pipeline([('scaler', StandardScaler()), ('logit', LogisticRegression(max_iter=1000))])
clf.fit(X_tr, y_tr_clf)
predc = clf.predict(X_te)
print(classification_report(y_te_clf, predc))
cm = confusion_matrix(y_te_clf, predc)
sns.heatmap(cm, annot=True, fmt='d'); plt.title('Confusion Matrix'); plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.77      0.66        53
#            1       0.52      0.30      0.38        43
#
#     accuracy                           0.56        96
#    macro avg       0.55      0.54      0.52        96
# weighted avg       0.55      0.56      0.54        96

# %% [markdown]
# ## Interpretation (Markdown)
# - What worked?
# - Where might assumptions fail?
# - How would you extend features or model?

# %% [markdown]
# ### Save Notebook
# Remember to save as `notebooks/modeling_<team>.ipynb`.

# %% [markdown]
# Interpretation (Executive Summary)
# Linear regression with scaling provided a solid baseline and RMSE showed predictive accuracy.
# Some assumptions (linearity, independence, homoscedasticity) may fail in financial time-series due to autocorrelation and volatility clustering.
# Extending features (e.g., volatility, momentum) and trying regularized or time-series models (Ridge, ARIMA, tree-based methods) could further improve performance.
